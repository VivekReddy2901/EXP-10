# %% [markdown]
# EXPERIMENT 10 : Study of Panda Library
#
# NAME : Vivek Reddy
#
# PRN : 25070123135

# %%
import pandas as pd

s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# create dataFrame
data = {
    "NAME": ["A","B","C"],
    "MARKS":[85,90,78]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   NAME  MARKS
# 0    A     85
# 1    B     90
# 2    C     78

# %%
print(df.shape)
# Out:
# (3, 2)

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 6

# %%
# to print name of columns
print(df.columns)
# Out:
# Index(['NAME', 'MARKS'], dtype='object')

# %%
#checks data type of each column
print(df.dtypes)
# Out:
# NAME     object
# MARKS     int64
# dtype: object

# %%
# only prints the column asked
print(df["NAME"])
print(df["MARKS"])
# Out:
# 0    A
# 1    B
# 2    C
# Name: NAME, dtype: object
# 0    85
# 1    90
# 2    78
# Name: MARKS, dtype: int64

# %%
# To display specific data
print(df.loc[0,"NAME"])
# Out:
# A

# %%
print(df.iloc[0,0])
print(df.iloc[0,1])
print(df.iloc[1])
# Out:
# A
# 85
# NAME      B
# MARKS    90
# Name: 1, dtype: object

# %%
df["GRADE"] = ["First Class","Distinction","Second Class"]
print(df)
# Out:
#   NAME  MARKS         GRADE
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# Update data in dataframe
df.loc[0,"MARKS"] = 88
df.iloc[0,1] = 88
print(df)
# Out:
#   NAME  MARKS         GRADE
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# delete a columns
# df.drop("GRADE", axis = 1, inplace=True)
df1 = df.drop("GRADE", axis = 1)
print(df1)
print(df)
# Out:
#   NAME  MARKS
# 0    A     88
# 1    B     90
# 2    C     78
#   NAME  MARKS         GRADE
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#perform basic statistical analysis
mean1 = df["MARKS"].mean()
print(mean1)
# Out:
# 85.33333333333333

# %%
min1 = df["MARKS"].min()
print(min1)
# Out:
# 78

# %%
max1 = df["MARKS"].max()
print(max1)
# Out:
# 90

# %%
#Apply condition (Filtering)
df[df["MARKS"] > 80]
# Out:
#   NAME  MARKS        GRADE
# 0    A     88  First Class
# 1    B     90  Distinction
